# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob

import matplotlib.pyplot as plt
# %load_ext google.colab.data_table


# %unload_ext google.colab.data_table

# %%
dict_tabs = {}
dict_mdg = {}
dict_not = {}
dict_dec = {}

for file in glob.glob('/content/drive/MyDrive/Colab Notebooks/protocol-J_Dataset/All Data Matix2/*.csv'):
  if 'TABS' in(file.split('/')[-1]):
    dict_tabs[int(file.split('/')[-1].split('_')[0][2:])] = file
  if 'DEC' in(file.split('/')[-1]):
    dict_dec[int(file.split('/')[-1].split('_')[0][2:])] = file
  if 'NOT' in(file.split('/')[-1]):
    dict_not[int(file.split('/')[-1].split('_')[0][2:])] = file 
  if 'MDG' in(file.split('/')[-1]):
    dict_mdg[int(file.split('/')[-1].split('_')[0][2:])] = file

# %%
len(dict_dec) , len(dict_tabs) ,len(dict_mdg) , len(dict_not)
# Out:
# (14, 14, 14, 12)

# %%
dict_tabs = dict(sorted(dict_tabs.items()))
dict_dec = dict(sorted(dict_dec.items()))
dict_not = dict(sorted(dict_not.items()))
dict_mdg = dict(sorted(dict_mdg.items()))

# %%
# for file in dict_mdg.keys():
#   df_ = pd.read_csv(dict_mdg[file], index_col=0)
#   for i in df_droped_cols_for_uniqueness:
#     print(i)
#     print(df_mdg[i].unique())

# %% [markdown]
# # Method 1 (in terms of selecting the first index)

# %%
dict_not.keys()
# Out:
# dict_keys([1, 2, 5, 6, 9, 10, 11, 14, 15, 16, 18, 19])

# %%
df_not= pd.DataFrame()
df_dec= pd.DataFrame()
df_mdg= pd.DataFrame()
df_tabs= pd.DataFrame()


for file in dict_not.keys():
  df_ = pd.read_csv(dict_not[file], index_col=0)
  df_ = df_.loc[np.where(df_['Timepoint']>0)[0][0]-120:]
  df_ = df_.iloc[np.where(df_['Glucose']>0)[0][0]: np.where(df_['Glucose']>0)[0][0]+840]
  # df_ = df_.iloc[np.where(df_['Timepoint']>0)[0][0]: np.where(df_['Timepoint']>0)[0][0]+720]
  if len(df_)<840:
    continue
  df_not = pd.concat([df_not,  df_], ignore_index=True)
# df_not.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/df_not_14hours.csv')
for file in dict_dec.keys():
  df_ = pd.read_csv(dict_dec[file], index_col=0)
  df_ = df_.loc[np.where(df_['Timepoint']>0)[0][0]-120:]
  df_ = df_.iloc[np.where(df_['Glucose']>0)[0][0]: np.where(df_['Glucose']>0)[0][0]+840]
  if len(df_)<840:
    continue
  df_dec = pd.concat([df_dec,  df_], ignore_index=True)
# df_dec.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/df_dec_14hours.csv')

for file in dict_mdg.keys():
  df_ = pd.read_csv(dict_mdg[file], index_col=0)
  df_ = df_.loc[np.where(df_['Timepoint']>0)[0][0]-120:]
  df_ = df_.iloc[np.where(df_['Glucose']>0)[0][0]: np.where(df_['Glucose']>0)[0][0]+840]
  if len(df_)<840:
    continue
  df_mdg = pd.concat([df_mdg,  df_], ignore_index=True)
# df_mdg.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/df_mdg_14hours.csv')

for file in dict_tabs.keys():
  df_ = pd.read_csv(dict_tabs[file], index_col=0)
  df_ = df_.loc[np.where(df_['Timepoint']>0)[0][0]-120:]
  df_ = df_.iloc[np.where(df_['Glucose']>0)[0][0]: np.where(df_['Glucose']>0)[0][0]+840]
  if len(df_)<840:
    continue
  df_tabs = pd.concat([df_tabs,  df_], ignore_index=True)
# df_tabs.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/df_tabs_14hours.csv')

# %% [markdown]
# ### df_dec --  ptd 6 and df_tabs --- pt 18 removed because of having few smaples (less tha 720 or 12 hours)

# %% [markdown]
# # Method 2 (in terms of selecting the first index)

# %%
df_dec.PtID.unique()
# Out:
# array([ 1,  2,  5,  9, 10, 11, 12, 13, 14, 15, 16, 18, 19])

# %%
df_not= pd.DataFrame()
df_dec= pd.DataFrame()
df_mdg= pd.DataFrame()
df_tabs= pd.DataFrame()


for file in dict_not.keys():
  df_ = pd.read_csv(dict_not[file], index_col=0)
  if -119 and 720 in df_.Timepoint.values :
    df_ = df_.loc[np.where(df_['Timepoint']==-119)[0][0]: np.where(df_['Timepoint']==720)[0][0]]
    if len(df_)<839:
      continue
    df_not = pd.concat([df_not,  df_], ignore_index=True)
  else:
    continue
df_not.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/df_not_14hours_index_aligned.csv')

for file in dict_dec.keys():
  df_ = pd.read_csv(dict_dec[file], index_col=0)
  if -119 and 720 in df_.Timepoint.values :
    df_ = df_.loc[np.where(df_['Timepoint']==-119)[0][0]: np.where(df_['Timepoint']==720)[0][0]]
    if len(df_)<839:
      continue
    df_dec = pd.concat([df_dec,  df_], ignore_index=True)
  else: 
    continue
df_dec.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/df_dec_14hours_index_aligned.csv')

for file in dict_mdg.keys():
  df_ = pd.read_csv(dict_mdg[file], index_col=0)
  if -119 and 720 in df_.Timepoint.values :
    df_ =df_.iloc[np.where(df_['Timepoint']==-120)[0][0]: np.where(df_['Timepoint']==720)[0][0]]
    if len(df_)<839:
      continue
    df_mdg = pd.concat([df_mdg,  df_], ignore_index=True)
  else:
    continue
df_mdg.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/df_mdg_14hours_index_aligned.csv')

for file in dict_tabs.keys():
  df_ = pd.read_csv(dict_tabs[file], index_col=0)
  if -119 and 720 in df_.Timepoint.values :
    df_ =df_.iloc[np.where(df_['Timepoint']==-120)[0][0]: np.where(df_['Timepoint']==720)[0][0]]
    if len(df_)<839:
      continue
    df_tabs = pd.concat([df_tabs,  df_], ignore_index=True)
  else: 
    continue
df_tabs.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/df_tabs_14hours_index_aligned.csv')

# %% [markdown]
# # Unitil 2.5 hours after the meal

# %%
cols = ['Time', 'Timepoint', 'PtID','Glucose','Carbohydrate', 'HeartRate',  'Insulin' ]
df_dec= pd.DataFrame()


for file in dict_dec.keys():
  if file==6:
    df_ = pd.read_csv(dict_dec[file], index_col=0)
    df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
    df_ = df_[cols]

# %%
df_not= pd.DataFrame()
df_dec= pd.DataFrame()
df_mdg= pd.DataFrame()
df_tabs= pd.DataFrame()


cols = ['Time', 'Timepoint', 'PtID','Glucose','Carbohydrate', 'HeartRate',  'Insulin' ]

for file in dict_not.keys():
  df_ = pd.read_csv(dict_not[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  if -60 and 2.5*60+75 in df_.Timepoint.values :
    df_ = df_.loc[np.where(df_['Timepoint']==-60)[0][0]: np.where(df_['Timepoint']==2.5*60+75)[0][0]]
    df_not = pd.concat([df_not,  df_], ignore_index=True)
  else:
    continue
  # df_ = df_.loc[np.where(df_['Timepoint']==-60)[0][0]: np.where(df_['Timepoint']==2.5*60+75)[0][0]]
  # df_not = pd.concat([df_not,  df_], ignore_index=True)

# df_not.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/-60minTo2.5hours_after_meal/df_not_-60minTo2.5hours_after_meal.csv')

for file in dict_dec.keys():
  df_ = pd.read_csv(dict_dec[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  if -60 and 2.5*60+75 in df_.Timepoint.values :
    df_ = df_.loc[np.where(df_['Timepoint']==-60)[0][0]: np.where(df_['Timepoint']==2.5*60+75)[0][0]]
    df_dec = pd.concat([df_dec,  df_], ignore_index=True)
  else:
    continue  

# df_dec.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/-60minTo2.5hours_after_meal/df_dec_-60minTo2.5hours_after_meal.csv')

for file in dict_mdg.keys():
  df_ = pd.read_csv(dict_mdg[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]  
  if -60 and 2.5*60+75 in df_.Timepoint.values :
    df_ = df_.loc[np.where(df_['Timepoint']==-60)[0][0]: np.where(df_['Timepoint']==2.5*60+75)[0][0]]
    df_mdg = pd.concat([df_mdg,  df_], ignore_index=True)
  else:
    continue  

# df_mdg.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/-60minTo2.5hours_after_meal/df_mdg_-60minTo2.5hours_after_meal.csv')

for file in dict_tabs.keys():
  df_ = pd.read_csv(dict_tabs[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  if -60 and 2.5*60+75 in df_.Timepoint.values :
    df_ = df_.loc[np.where(df_['Timepoint']==-60)[0][0]: np.where(df_['Timepoint']==2.5*60+75)[0][0]]
    df_tabs = pd.concat([df_tabs,  df_], ignore_index=True)
  else:
    continue  
  
# df_tabs.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/-60minTo2.5hours_after_meal/df_tabs_-60minTo2.5hours_after_meal.csv')

# %%
len(df_not.PtID.unique()), len(df_tabs.PtID.unique()) , len(df_mdg.PtID.unique()),len(df_dec.PtID.unique())
# Out:
# (12, 14, 14, 13)

# %%
# import scipy.io as sio

# cols = ['Time', 'Timepoint', 'PtID','Glucose','Carbohydrate', 'HeartRate',  'Insulin' ]
pw_path = '/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/-60minTo2.5hours_after_meal'

# df_not.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_mdg.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_tabs.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_dec.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)

for ii in df_not.PtID.unique():
  df_not[cols][df_not.PtID==ii].to_csv(os.path.join(pw_path,'df_not_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_not_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_not[cols][df_not.PtID==ii].replace(np.nan, '', regex=True).items()})

for ii in df_mdg.PtID.unique():
  df_mdg[cols][df_mdg.PtID==ii].to_csv(os.path.join(pw_path,'df_mdg_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_mdg_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_mdg[cols][df_mdg.PtID==ii].replace(np.nan, '', regex=True).items()})
for ii in df_tabs.PtID.unique():
  df_tabs[cols][df_tabs.PtID==ii].to_csv(os.path.join(pw_path,'df_tabs_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_tabs_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_tabs[cols][df_tabs.PtID==ii].replace(np.nan, '', regex=True).items()})
for ii in df_dec.PtID.unique():
  df_dec[cols][df_dec.PtID==ii].to_csv(os.path.join(pw_path,'df_50dec_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_dec_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_dec[cols][df_dec.PtID==ii].replace(np.nan, '', regex=True).items()})

# %% [markdown]
# # Complete Dataset

# %%
dfnot=pd.DataFrame()
# Out:
# 1440

# %%
df_not= pd.DataFrame()
df_dec= pd.DataFrame()
df_mdg= pd.DataFrame()
df_tabs= pd.DataFrame()


cols = ['Time', 'Timepoint', 'PtID','Glucose','Carbohydrate', 'HeartRate',  'Insulin' ]

for file in dict_not.keys():
  df_ = pd.read_csv(dict_not[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  df_not = pd.concat([df_not,  df_], ignore_index=True)

df_not.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/all_data_points/df_not_all_data_points.csv')

for file in dict_dec.keys():
  df_ = pd.read_csv(dict_dec[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  df_dec = pd.concat([df_dec,  df_], ignore_index=True)

df_dec.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/all_data_points/df_dec_all_data_points.csv')

for file in dict_mdg.keys():
  df_ = pd.read_csv(dict_mdg[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  df_mdg = pd.concat([df_mdg,  df_], ignore_index=True)

df_mdg.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/all_data_points/df_mdg_all_data_points.csv')

for file in dict_tabs.keys():
  df_ = pd.read_csv(dict_tabs[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  df_tabs = pd.concat([df_tabs,  df_], ignore_index=True)

df_tabs.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/all_data_points/df_tabs_all_data_points.csv')

# %%
# import scipy.io as sio

# cols = ['Time', 'Timepoint', 'PtID','Glucose','Carbohydrate', 'HeartRate',  'Insulin' ]
pw_path = '/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/all_data_points'

# df_not.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_mdg.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_tabs.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_dec.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)

for ii in df_not.PtID.unique():
  df_not[cols][df_not.PtID==ii].to_csv(os.path.join(pw_path,'df_not_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_not_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_not[cols][df_not.PtID==ii].replace(np.nan, '', regex=True).items()})

for ii in df_mdg.PtID.unique():
  df_mdg[cols][df_mdg.PtID==ii].to_csv(os.path.join(pw_path,'df_mdg_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_mdg_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_mdg[cols][df_mdg.PtID==ii].replace(np.nan, '', regex=True).items()})
for ii in df_tabs.PtID.unique():
  df_tabs[cols][df_tabs.PtID==ii].to_csv(os.path.join(pw_path,'df_tabs_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_tabs_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_tabs[cols][df_tabs.PtID==ii].replace(np.nan, '', regex=True).items()})
for ii in df_dec.PtID.unique():
  df_dec[cols][df_dec.PtID==ii].to_csv(os.path.join(pw_path,'df_50dec_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_dec_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_dec[cols][df_dec.PtID==ii].replace(np.nan, '', regex=True).items()})

# %% [markdown]
# # shorter Time Interval
# ## Time Interval:  -10 mins to +75 minutes wrt the start of the exercise session

# %%
df_not= pd.DataFrame()
df_dec= pd.DataFrame()
df_mdg= pd.DataFrame()
df_tabs= pd.DataFrame()


cols = ['Time', 'Timepoint', 'PtID','Glucose','Carbohydrate', 'HeartRate',  'Insulin' ]

for file in dict_not.keys():
  df_ = pd.read_csv(dict_not[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  if -10 and 75 in df_.Timepoint.values :
    df_ = df_.loc[np.where(df_['Timepoint']==-10)[0][0]: np.where(df_['Timepoint']==75)[0][0]]

    df_not = pd.concat([df_not,  df_], ignore_index=True)
  else:
    continue
df_not.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/shorter_time_interval/df_not_85min_index_aligned.csv')

for file in dict_dec.keys():
  df_ = pd.read_csv(dict_dec[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  if -10 and 75 in df_.Timepoint.values :
    df_ = df_.loc[np.where(df_['Timepoint']==-10)[0][0]: np.where(df_['Timepoint']==75)[0][0]]

    df_dec = pd.concat([df_dec,  df_], ignore_index=True)
  else: 
    continue
df_dec.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/shorter_time_interval/df_dec_85min_index_aligned.csv')

for file in dict_mdg.keys():
  df_ = pd.read_csv(dict_mdg[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  if -10 and 76 in df_.Timepoint.values :
    df_ =df_.iloc[np.where(df_['Timepoint']==-10)[0][0]: np.where(df_['Timepoint']==76)[0][0]]

    df_mdg = pd.concat([df_mdg,  df_], ignore_index=True)
  else:
    continue
df_mdg.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/shorter_time_interval/df_mdg_85min_index_aligned.csv')

for file in dict_tabs.keys():
  df_ = pd.read_csv(dict_tabs[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  if -10 and 76 in df_.Timepoint.values :
    df_ =df_.iloc[np.where(df_['Timepoint']==-10)[0][0]: np.where(df_['Timepoint']==76)[0][0]]

    df_tabs = pd.concat([df_tabs,  df_], ignore_index=True)
  else: 
    continue
df_tabs.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/shorter_time_interval/df_tabs_85min_index_aligned.csv')

# %%
len(df_not.PtID.unique()) , len(df_tabs.PtID.unique()) , len(df_mdg.PtID.unique()) , len(df_dec.PtID.unique())
# Out:
# (12, 14, 14, 14)

# %%
len(df_not) , len(df_tabs) , len(df_mdg) , len(df_dec)
# Out:
# (1032, 1204, 1204, 1204)

# %%
import scipy.io as sio

# cols = ['Time', 'Timepoint', 'PtID','Glucose','Carbohydrate', 'HeartRate',  'Insulin' ]
pw_path = '/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/shorter_time_interval'

# df_not.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_mdg.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_tabs.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_dec.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)

for ii in df_not.PtID.unique():
  df_not[cols][df_not.PtID==ii].to_csv(os.path.join(pw_path,'df_not_pw/patient_'+str(ii)+'.csv'))
  sio.savemat(os.path.join(pw_path,'df_not_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_not[cols][df_not.PtID==ii].replace(np.nan, '', regex=True).items()})

for ii in df_mdg.PtID.unique():
  df_mdg[cols][df_mdg.PtID==ii].to_csv(os.path.join(pw_path,'df_mdg_pw/patient_'+str(ii)+'.csv'))
  sio.savemat(os.path.join(pw_path,'df_mdg_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_mdg[cols][df_mdg.PtID==ii].replace(np.nan, '', regex=True).items()})
for ii in df_tabs.PtID.unique():
  df_tabs[cols][df_tabs.PtID==ii].to_csv(os.path.join(pw_path,'df_tabs_pw/patient_'+str(ii)+'.csv'))
  sio.savemat(os.path.join(pw_path,'df_tabs_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_tabs[cols][df_tabs.PtID==ii].replace(np.nan, '', regex=True).items()})
for ii in df_dec.PtID.unique():
  df_dec[cols][df_dec.PtID==ii].to_csv(os.path.join(pw_path,'df_dec_pw/patient_'+str(ii)+'.csv'))
  sio.savemat(os.path.join(pw_path,'df_dec_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_dec[cols][df_dec.PtID==ii].replace(np.nan, '', regex=True).items()})

# %% [markdown]
# # Excesrcise interval

# %%
df_not= pd.DataFrame()
df_dec= pd.DataFrame()
df_mdg= pd.DataFrame()
df_tabs= pd.DataFrame()


cols = ['Time', 'Timepoint', 'PtID','Glucose','Carbohydrate', 'HeartRate',  'Insulin' ]

for file in dict_not.keys():
  df_ = pd.read_csv(dict_not[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  if 1 and 45 in df_.Timepoint.values :
    df_ = df_.loc[np.where(df_['Timepoint']==1)[0][0]: np.where(df_['Timepoint']==45)[0][0]]

    df_not = pd.concat([df_not,  df_], ignore_index=True)
  else:
    continue
df_not.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/exercise_time_interval/df_not_exercise_index_aligned.csv')

for file in dict_dec.keys():
  df_ = pd.read_csv(dict_dec[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  if 1 and 45 in df_.Timepoint.values :
    df_ = df_.loc[np.where(df_['Timepoint']==1)[0][0]: np.where(df_['Timepoint']==45)[0][0]]

    df_dec = pd.concat([df_dec,  df_], ignore_index=True)
  else: 
    continue
df_dec.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/exercise_time_interval/df_dec_exercise_index_aligned.csv')

for file in dict_mdg.keys():
  df_ = pd.read_csv(dict_mdg[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  if 1 and 45 in df_.Timepoint.values :
    df_ =df_.iloc[np.where(df_['Timepoint']==1)[0][0]: np.where(df_['Timepoint']==45)[0][0]]

    df_mdg = pd.concat([df_mdg,  df_], ignore_index=True)
  else:
    continue
df_mdg.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/exercise_time_interval/df_mdg_exercise_index_aligned.csv')

for file in dict_tabs.keys():
  df_ = pd.read_csv(dict_tabs[file], index_col=0)
  df_.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
  df_ = df_[cols]
  if 1 and 45 in df_.Timepoint.values :
    df_ =df_.iloc[np.where(df_['Timepoint']==1)[0][0]: np.where(df_['Timepoint']==45)[0][0]]

    df_tabs = pd.concat([df_tabs,  df_], ignore_index=True)
  else: 
    continue
df_tabs.to_csv('/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/exercise_time_interval/df_tabs_exercise_index_aligned.csv')

# %%
pw_path = '/content/drive/MyDrive/Colab Notebooks/LMEM-SHAP/preprocessed_data/exercise_time_interval'

# df_not.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_mdg.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_tabs.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)
# df_dec.rename(columns={"Carbohydrate [gram]":"Carbohydrate"}, inplace=True)

for ii in df_not.PtID.unique():
  df_not[cols][df_not.PtID==ii].to_csv(os.path.join(pw_path,'df_not_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_not_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_not[cols][df_not.PtID==ii].replace(np.nan, '', regex=True).items()})

for ii in df_mdg.PtID.unique():
  df_mdg[cols][df_mdg.PtID==ii].to_csv(os.path.join(pw_path,'df_mdg_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_mdg_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_mdg[cols][df_mdg.PtID==ii].replace(np.nan, '', regex=True).items()})
for ii in df_tabs.PtID.unique():
  df_tabs[cols][df_tabs.PtID==ii].to_csv(os.path.join(pw_path,'df_tabs_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_tabs_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_tabs[cols][df_tabs.PtID==ii].replace(np.nan, '', regex=True).items()})
for ii in df_dec.PtID.unique():
  df_dec[cols][df_dec.PtID==ii].to_csv(os.path.join(pw_path,'df_dec_pw/patient_'+str(ii)+'.csv'))
  # sio.savemat(os.path.join(pw_path,'df_dec_pw/patient_'+str(ii)+'.mat'),  {name: col.values for name, col in df_dec[cols][df_dec.PtID==ii].replace(np.nan, '', regex=True).items()})
